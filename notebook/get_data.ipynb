# %%
import pandas as pd
import sys

# %%
def get_data(PATH: str, file_name: str) -> pd.DataFrame:
    try:
        df = pd.read_excel(PATH+file_name, header=1)
        # fill empty space with _
        csv_filename = file_name.replace(" ","_")
        df.to_csv(PATH+csv_filename[:-5]+".csv", index=False)
        df = pd.read_csv(PATH+csv_filename[:-5]+".csv")
        return df
    except:
        print("Error: file not found")
        sys.exit(1)

df = get_data("../data/", "default of credit card clients.xls")
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df = pd.read_csv("../data/default_of_credit_card_client.csv")
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df["LIMIT_BAL"].unique()
# Out:
# [  20000  120000   90000   50000  500000  100000  140000  200000  260000
#   630000   70000  250000  320000  360000  180000  130000  450000   60000
#   230000  160000  280000   10000   40000  210000  150000  380000  310000
#   400000   80000  290000  340000  300000   30000  240000  470000  480000
#   350000  330000  110000  420000  170000  370000  270000  220000  190000
#   510000  460000  440000  410000  490000  390000  580000  600000  620000
#   610000  700000  670000  680000  430000  550000  540000 1000000  530000
#   710000  560000  520000  750000  640000   16000  570000  590000  660000
#   720000  327680  740000  800000  760000  690000  650000  780000  730000]

# %%
df["LIMIT_BAL"].unique()
# count the number of individule have this unique values
df["LIMIT_BAL"].value_counts().sort_values(ascending=True)
# Out:
# LIMIT_BAL
# 690000        1
# 1000000       1
# 760000        1
# 327680        1
# 740000        2
#            ...
# 200000     1528
# 80000      1567
# 30000      1610
# 20000      1976
# 50000      3365
# Name: count, Length: 81, dtype: int64

# %%
df[df["default payment next month"]==1]["MARRIAGE"].hist()
# Out:
# <Axes: >

# %%
print(df.groupby("EDUCATION").size())
print(df.groupby("EDUCATION").size()/len(df))
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# dtype: int64
# EDUCATION
# 0    0.000467
# 1    0.352833
# 2    0.467667
# 3    0.163900
# 4    0.004100
# 5    0.009333
# 6    0.001700
# dtype: float64

# %%
47+16+0.4 + 35 = 98.4

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd  # Assuming you will load the data into a pandas DataFrame

# Assuming 'df' is your DataFrame and it contains the necessary columns
# Replace 'df' with the actual name of your DataFrame variable

skewness_dict = {
    'PAY': df[['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']].skew().values,
    'BILL_AMT': df[['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']].skew().values,
    'PAY_AMT': df[['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']].skew().values
}

# Create a line chart for each feature set
plt.figure(figsize=(14, 6))

# X-axis values
time_periods = [1, 2, 3, 4, 5, 6]

# Plot each line
for feature, skewness in skewness_dict.items():
    plt.plot(time_periods, skewness, marker='o', label=f'Skewness of {feature}')

plt.legend()
plt.title('Skewness of PAY, BILL_AMT, and PAY_AMT Variables Over Time')
plt.xlabel('Time Period')
plt.ylabel('Skewness')
plt.xticks(time_periods)  # Ensure x-axis ticks show each time period
plt.grid(True)  # Optional: Add grid for better readability

# Show plot
plt.show()

# %%
sns.set_theme(style="white")
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
cleaned_df = pd.read_csv('../data/clustered_data.csv')

# %%
sns.set_theme(style="white")
corr = cleaned_df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
# count the number of default and non-default
df.groupby("default payment next month").size()
# Out:
# default payment next month
# 0    23364
# 1     6636
# dtype: int64

# %%
# calcualte the percentage of default and non-default
df.groupby("default payment next month").size()/len(df)
# Out:
# default payment next month
# 0    0.7788
# 1    0.2212
# dtype: float64

# %%
# check distribution of age
df["AGE"].hist()
# Out:
# <Axes: >

# %%
# find the majority of age group
df["AGE"].mode()
# Out:
# 0    23
# Name: AGE, dtype: int64

# %%
# Find the distribution of dufault payment by age group
# draw a histogram, default payment by age
df[df["default payment next month"]==1]["AGE"].hist()
# Out:
# <Axes: >

# %%
# draw a histogram, default payment by education
df[df["default payment next month"]==1]["MARRIAGE"].hist()
# Out:
# <Axes: >

# %%
# draw a histogram, default payment by limit balance
df[df["default payment next month"]==1]["LIMIT_BAL"].hist()
# Out:
# <Axes: >

# %%
# histogram of limit balance
df["LIMIT_BAL"].hist()
# Out:
# <Axes: >

# %%
# skewness of limit balance
df["LIMIT_BAL"].skew()
# Out:
# 0.992866960519544

# %%
# skewness of the data:
df.skew()
# Out:
# ID                             0.000000
# LIMIT_BAL                      0.992867
# SEX                           -0.424183
# EDUCATION                      0.970972
# MARRIAGE                      -0.018742
# AGE                            0.732246
# PAY_0                          0.731975
# PAY_2                          0.790565
# PAY_3                          0.840682
# PAY_4                          0.999629
# PAY_5                          1.008197
# PAY_6                          0.948029
# BILL_AMT1                      2.663861
# BILL_AMT2                      2.705221
# BILL_AMT3                      3.087830
# BILL_AMT4                      2.821965
# BILL_AMT5                      2.876380
# BILL_AMT6                      2.846645
# PAY_AMT1                      14.668364
# PAY_AMT2                      30.453817
# PAY_AMT3                      17.216635
# PAY_AMT4                      12.904985
# PAY_AMT5                      11.127417
# ...

# %%
# count the uniuqe values of LIMIT_BAL less than 21 people
df["LIMIT_BAL"].value_counts().sort_index()
# Out:
# LIMIT_BAL
# 10000       493
# 16000         2
# 20000      1976
# 30000      1610
# 40000       230
#            ...
# 750000        4
# 760000        1
# 780000        2
# 800000        2
# 1000000       1
# Name: count, Length: 81, dtype: int64

# %%
# find the range of age
df["AGE"].min(), df["AGE"].max()
# Out:
# (21, 79)

# %%
df.groupby("SEX").size()
# Out:
# SEX
# 1    11888
# 2    18112
# dtype: int64

# %%
df.groupby("SEX").size()/len(df)
# Out:
# SEX
# 1    0.396267
# 2    0.603733
# dtype: float64

# %%
df.groupby("EDUCATION").size()
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# dtype: int64

# %%
# calcualte the percentage of default and non-default
df.groupby("EDUCATION").size()/len(df)
# Out:
# EDUCATION
# 0    0.000467
# 1    0.352833
# 2    0.467667
# 3    0.163900
# 4    0.004100
# 5    0.009333
# 6    0.001700
# dtype: float64

# %%
df.groupby("MARRIAGE").size()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# dtype: int64

# %%
# calcualte the percentage of default and non-default
df.groupby("MARRIAGE").size()/len(df)
# Out:
# MARRIAGE
# 0    0.001800
# 1    0.455300
# 2    0.532133
# 3    0.010767
# dtype: float64
